# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Music notes
# https://www.kaggle.com/adithyakag/musicnotedetection/version/1
#
# 1. 你選的這組資料為何重要
#     每天聽的音樂
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#    Adithya
#    Generated wav files of different notes using garageband. Use this data to classify musical notes.
#
# 3. 蒐集而來的資料型態為何
#    wave- stereo, sample rate: 44100 , 8bits
#
# 4. 這組資料想解決的問題如何評估
#   Create an app that could generate instrumentals of songs that we listen daily.
#   1.是否有Ground Truth data
#   2.是分類問題, 還是生成問題
#   3.是否資料足夠

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#    業績高: 載客率高 / 所有乘客的乘車總距離是否增加
#    業績低: 載客率低 / 所有乘客的乘車總距離是否減少
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#     -.Uber乘車資料
#     -.透過Kaggle或是Google的open dataset
#
# 3. 蒐集而來的資料型態為何
#
#     十進位數字
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#     資料集需要分為訓練資料與測試資料
#     測試資料正確率需要達到

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
MSE=0.1
def mean_squared_error(A,B):
    mse = ((A - B)**2).mean()
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
#MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
#print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 246.686
